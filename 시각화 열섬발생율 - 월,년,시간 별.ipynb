# %%
# 연도별, 지역별, 월별, 시간별 열섬 발생율을 살펴봄

# %%
import pandas as pd
import numpy as np

import platform
import matplotlib.pyplot as plt

# %matplotlib inline

path = "c:/Windows/Fonts/malgun.ttf"
from matplotlib import font_manager, rc
if platform.system() == 'Darwin':
    rc('font', family='AppleGothic')
elif platform.system() == 'Windows':
    font_name = font_manager.FontProperties(fname=path).get_name()
    rc('font', family=font_name)
else:
    print('Unknown system... sorry~~~~')    

plt.rcParams['axes.unicode_minus'] = False

# %%
year = pd.read_csv('연도별_지역별_열섬발생비율.csv', engine='python', encoding='CP949')  #연도별 열섬 발생율을 따로 구해서 병합한 자료
year2 = pd.read_csv('연도별_지역별_열섬발생비율2.csv', engine='python', encoding='CP949')

# %%
year.head()
# Out:
#   address      2014      2015      2016      2017
# 0     강남구  0.219905  0.230193  0.211800  0.251605
# 1     강동구  0.274586  0.286938  0.265592  0.280151
# 2     강북구  0.257862  0.256683  0.210395  0.278348
# 3     강서구  0.225774  0.245220  0.227478  0.234271
# 4     관악구  0.258117  0.272366  0.255874  0.294264

# %%
Year=year.T

Year.columns=list(year.T.iloc[0])

#Year.drop('address')

Year=Year[1:]

# %%
#year.address.values
# Out:
# array(['강남구', '강동구', '강북구', '강서구', '관악구', '광진구', '구로구', '금천구', '노원구',
#        '도봉구', '동대문구', '동작구', '마포구', '서대문구', '서초구', '성동구', '성북구', '송파구',
#        '양천구', '영등포구', '용산구', '은평구', '종로구', '중구', '중랑구'], dtype=object)

# %%
#year['address'].unique()
# Out:
# array(['강남구', '강동구', '강북구', '강서구', '관악구', '광진구', '구로구', '금천구', '노원구',
#        '도봉구', '동대문구', '동작구', '마포구', '서대문구', '서초구', '성동구', '성북구', '송파구',
#        '양천구', '영등포구', '용산구', '은평구', '종로구', '중구', '중랑구'], dtype=object)

# %%
plt.figure(figsize=(20,10))
plt.plot(Year)
plt.xticks(np.arange(0, 4, step=1)) #2014 ~ 2017 : 4Years
plt.legend(target_col, loc='right')
plt.title('연도별 열섬 발생율',size=17)
plt.grid()
plt.show()
# 연도별로 큰차이는 없음

# %%
month = pd.read_csv('월별_지역별_열섬발생비율.csv', engine='python', encoding='CP949') # 연평균 합, -> 월별로 집계

# %%
month.drop('Month',axis=1,inplace=True)

# %%
month
# Out:
#          강남구       강동구       강북구       강서구       관악구       광진구       구로구  \
# 0   0.308348  0.364974  0.285865  0.290213  0.365484  0.377869  0.343706
# 1   0.258856  0.308995  0.254784  0.221311  0.292914  0.315850  0.275240
# 2   0.281064  0.324591  0.300068  0.237645  0.287458  0.347643  0.262283
# 3   0.197420  0.239341  0.227807  0.195356  0.215569  0.255639  0.193950
# 4   0.221495  0.261622  0.259058  0.211424  0.230203  0.281490  0.197942
# 5   0.122214  0.174456  0.169525  0.122758  0.141551  0.205692  0.116441
# 6   0.060758  0.093255  0.118009  0.076692  0.086566  0.120459  0.080515
# 7   0.109752  0.160777  0.155351  0.163904  0.167183  0.194591  0.190068
# 8   0.283189  0.353886  0.333901  0.383212  0.364456  0.369373  0.393558
# 9   0.354583  0.400555  0.355478  0.414410  0.404114  0.427975  0.414779
# 10  0.275602  0.327427  0.267904  0.263131  0.313354  0.334056  0.321057
# 11  0.269121  0.333051  0.225570  0.297608  0.334491  0.318182  0.335296
#
# ...

# %%
plt.figure(figsize=(20,10))
ax=plt.subplot(111)
plt.xlabel('월') 
plt.ylabel('열섬 발생율')
ax.set_xlim(1, 13)  # x축 출력 범위
dim=np.arange(1,13,1) 
ax.set_xticks(dim)  # 월 별 x축 설정

ax.plot(dim,month) 
plt.legend(target_col, loc='right')
plt.title('월별 열섬 발생율', size=17)
plt.grid()
plt.show()

# %%
Hour = pd.read_csv('시간별_지역별_열섬발생비율.csv', engine='python', encoding='CP949')
Hour.head()
# Out:
#    Time       강남구       강동구       강북구       강서구       관악구       광진구       구로구  \
# 0  0:00  0.507123  0.548647  0.531086  0.473854  0.522509  0.573758  0.494245
# 1  1:00  0.463345  0.524838  0.495880  0.409091  0.512070  0.573134  0.459323
# 2  2:00  0.484009  0.543885  0.507865  0.439871  0.539927  0.584512  0.487419
# 3  3:00  0.484741  0.541219  0.518657  0.470921  0.550257  0.588980  0.513262
# 4  4:00  0.490754  0.541278  0.513816  0.480676  0.559707  0.588279  0.534632
#
#         금천구       노원구    ...          성동구       성북구       송파구       양천구  \
# 0  0.492968  0.543860    ...     0.508121  0.534697  0.524629  0.517766
# 1  0.482143  0.518222    ...     0.447086  0.508487  0.461358  0.502177
# 2  0.510417  0.517518    ...     0.454962  0.518328  0.479150  0.524709
# 3  0.524664  0.505814    ...     0.452959  0.520910  0.450671  0.542692
# 4  0.558692  0.501094    ...     0.458301  0.513216  0.428685  0.563452
#
#        영등포구       용산구       은평구       종로구        중구       중랑구
# ...

# %%
Hour[list(Hour.columns[1:])]
# Out:
#          강남구       강동구       강북구       강서구       관악구       광진구       구로구  \
# 0   0.507123  0.548647  0.531086  0.473854  0.522509  0.573758  0.494245
# 1   0.463345  0.524838  0.495880  0.409091  0.512070  0.573134  0.459323
# 2   0.484009  0.543885  0.507865  0.439871  0.539927  0.584512  0.487419
# 3   0.484741  0.541219  0.518657  0.470921  0.550257  0.588980  0.513262
# 4   0.490754  0.541278  0.513816  0.480676  0.559707  0.588279  0.534632
# 5   0.483178  0.539293  0.507159  0.512097  0.575624  0.581709  0.551153
# 6   0.473571  0.530980  0.503771  0.533065  0.563142  0.568773  0.550578
# 7   0.411095  0.468728  0.452273  0.485460  0.491176  0.486266  0.517366
# 8   0.249292  0.322789  0.322532  0.363636  0.353157  0.350969  0.409777
# 9   0.076868  0.145022  0.153383  0.183374  0.191285  0.174332  0.243165
# 10  0.012100  0.054598  0.056391  0.056052  0.087278  0.050075  0.108069
# 11  0.004317  0.018142  0.019667  0.020000  0.022523  0.014471  0.030103
# ...

# %%
plt.figure(figsize=(20,10))
ax=plt.subplot(111)
plt.xlabel('시간') 
plt.ylabel('열섬 발생율')
ax.set_xlim(0, 24)
dim=np.arange(0,24,1)
ax.set_xticks(dim)

ax.plot(dim,Hour[list(Hour.columns[1:])])
plt.legend(list(Hour.columns[1:]), loc='best')
plt.title('시간별 열섬 발생율',size=17)
plt.grid()
plt.show()

# %% [markdown]
# 시간별 차이 발생 :<br/>
#    - 낮시간 10시 ~ 18시 까지 일사를 비슷하게 받기 때문에 온도차가 거의 나지 않음<br/>
#    - 이후 시간대 : 도시 특성마다 냉각되는 시간이 다름
